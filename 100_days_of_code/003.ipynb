# %% [markdown]
# # Day 3 - Control flow and logical operators

# %% [markdown]
# ## Python Pizza
# Based on a user's order, work out their final bill.<br>
# Use the `input()` function to get a user's preference and then add up the total for their order and tell them how much they have to pay.
#
# * Small pizza (S): $15
# * Medium pizza (M): $20
# * Large pizza (L): $25
#
# * Add pepperoni for small pizza (Y/N): +$2
# * Add pepperoni for medium or large pizza (Y/N): +$3
# * Add extra cheese for any size pizza (Y/N): +$1

# %%
print("Welcome to Python Pizza Deliveries!")
size = input("What size pizza do you want? S, M, L: ")
pepperoni = input("Do you want pepperoni on your pizza? Y or N: ")
extra_cheese = input("Do you want extra cheese? Y or N: ")
bill = 0

if size == "S":
    bill += 15
elif size == "M":
    bill += 20
elif size == "L":
    bill += 25

if pepperoni == "Y" and size == "S":
    bill += 2
elif pepperoni == "Y":
    bill += 3

if extra_cheese == "Y":
    bill += 1

print(f"Total cost comes to {bill}")
# Out:
# Welcome to Python Pizza Deliveries!
# Total cost comes to 23

# %%
# Day 3 Project
print("""
Welcome to Treasure Island.
Your mission is to find the treasure.
""")

direction = input("""You come across 3 paths.
                  Do you go Straight, Left, or Right?
                  """).strip()

if not direction or direction[0].upper() != "L":
    print("You fall into a hole.\n Game Over.")
    exit()

action = input("""You come across a river.
               Do you Wait for low tide or Swim across now?
               """).strip()

if not action or action[0].upper() != "W":
    print("You have been attacked by trout.\nGame Over.")
    exit()

colour = input("""You see a rainbow number of doors:
               Red, Orange, Blue, Yellow, etc.
               Which do you go through?
               """).strip()

if not colour or colour[0].upper() != "Y":
    print("You are sucked into the void.\nGame Over.")
else:
    print("You have found the gold and are now rich!")
# Out:
# Welcome to Treasure Island.
# Your mission is to find the treasure.
#
# You enter the void. Game Over.
